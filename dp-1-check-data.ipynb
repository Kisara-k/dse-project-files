# %%
# !wget https://raw.githubusercontent.com/nuuuwan/lk_legal_docs/main/data/all.tsv
# Out:
# --2025-07-18 06:00:32--  https://raw.githubusercontent.com/nuuuwan/lk_legal_docs/main/data/all.tsv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16759844 (16M) [text/plain]
# Saving to: ‘all.tsv’
#
# all.tsv             100%[===================>]  15.98M  --.-KB/s    in 0.07s
#
# 2025-07-18 06:00:32 (242 MB/s) - ‘all.tsv’ saved [16759844/16759844]

# %%
import warnings
warnings.filterwarnings('ignore') 

import pandas as pd
pd.set_option('display.max_columns', None)     # Show all columns without truncation
pd.set_option('display.max_colwidth', None)    # Show full content in each cell

# %%
df = pd.read_csv('all.tsv', sep='\t')
df
# Out:
#         doc_type_name        date  \
# 0               bills  2025-07-08
# 1      extra-gazettes  2025-07-07
# 2      extra-gazettes  2025-07-07
# 3      extra-gazettes  2025-07-07
# 4      extra-gazettes  2025-07-07
# ...               ...         ...
# 43964            acts  1981-02-11
# 43965            acts  1981-02-11
# 43966            acts  1981-01-29
# 43967            acts  1981-01-29
# 43968            acts  1981-01-22
#
#                                                                                                                                                                      description  \
# 0                                                                                                                                                    Penal Code (Amendment) - GS
# 1                                                                       Presidential Secretariat - Appointed Secretary to the Ministry Finance Planning and Economic Development
# ...

# %%
df['doc_type_name'].value_counts()
# Out:
# doc_type_name
# extra-gazettes    34707
# gazettes           6267
# acts               1647
# bills              1348
# Name: count, dtype: int64

# %%
# Missing Values of Each Type
df.groupby('doc_type_name').apply(lambda g: g.isnull().sum())
# Out:
#                 doc_type_name  date  description  source_url_si  \
# doc_type_name
# acts                        0     0            0            110
# bills                       0     0            0             15
# extra-gazettes              0     0            0            552
# gazettes                    0     0            0             45
#
#                 source_url_ta  source_url_en  doc_num  id  dir_data
# doc_type_name
# acts                      494            448        0   0         0
# bills                      21              0        0   0         0
# extra-gazettes           2839           1579        0   0         0
# gazettes                  416            288        0   0         0

# %%
# Check for all sources missing
print(df[(df[['source_url_si', 'source_url_ta', 'source_url_en']].replace('', pd.NA).isna().all(axis=1))].groupby('doc_type_name').size())

# At least ENG or SI
print(df[(df[['source_url_si', 'source_url_en']].replace('', pd.NA).isna().all(axis=1))].groupby('doc_type_name').size())
# Out:
# Series([], dtype: int64)
# doc_type_name
# acts              36
# extra-gazettes    70
# gazettes           3
# dtype: int64

# %%
# !gdown https://drive.google.com/uc?id=1F_WDXotjwawHL2HO4FEAKungLN-rPGN6
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1F_WDXotjwawHL2HO4FEAKungLN-rPGN6
# To: /kaggle/working/all_manual.tsv
# 100%|██████████████████████████████████████| 16.7M/16.7M [00:00<00:00, 41.2MB/s]

# %%
df_m = pd.read_csv('all_manual.tsv', sep='\t')
df_m
# Out:
#       doc_type_name        date  \
# 0              acts  2021-10-26
# 1              acts  2021-01-18
# 2              acts  2021-11-12
# 3              acts  2021-07-16
# 4              acts  2021-08-23
# ...             ...         ...
# 44038      gazettes  2012-06-01
# 44039      gazettes  2012-04-06
# 44040      gazettes  2012-06-22
# 44041      gazettes  2012-10-19
# 44042      gazettes  2012-04-06
#
#                                                         description  \
# 0                 Youthful Offenders (Training Schools) (Amendment)
# 1                                            Penal Code (Amendment)
# 2                              Immigrants and Emigrants (Amendment)
# 3                             Code of Criminal Procedure (Amedment)
# 4      Coronavirus Disease 2019 (Covid - 19) (Temporary Provisions)
# ...                                                             ...
# 44038                                           (IIA) - Advertising
# ...

# %%
pd.concat([df, df_m, df_m]).drop_duplicates(keep=False)
# Out:
# Empty DataFrame
# Columns: [doc_type_name, date, description, source_url_si, source_url_ta, source_url_en, doc_num, id, dir_data]
# Index: []

# %%
 pd.concat([df_m, df, df]).drop_duplicates(keep=False)
# Out:
#         doc_type_name        date  \
# 2582            bills  2025-07-09
# 2598            bills  2025-07-08
# 2599            bills  2025-07-17
# 24669  extra-gazettes  2025-06-18
# 24731  extra-gazettes  2025-06-18
# ...               ...         ...
# 41916        gazettes  2025-07-11
# 41934        gazettes  2025-07-11
# 41941        gazettes  2025-07-11
# 41977        gazettes  2025-07-11
# 41978        gazettes  2025-07-11
#
#                                                                                                                                                      description  \
# 2582                                                                                                                           Rubber Control (Amendment) - Bill
# 2598                                                                                                                           National Audit (Amendment) - Bill
# ...
