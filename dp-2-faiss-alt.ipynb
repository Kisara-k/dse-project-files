# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0.post1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<3.0,>=1.25.0->faiss-cpu) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<3.0,>=1.25.0->faiss-cpu) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<3.0,>=1.25.0->faiss-cpu) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<3.0,>=1.25.0->faiss-cpu) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<3.0,>=1.25.0->faiss-cpu) (2024.2.0)
# Downloading faiss_cpu-1.11.0.post1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 57.9 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.11.0.post1

# %%
import pandas as pd
import numpy as np
import faiss
from sentence_transformers import SentenceTransformer
from openai import OpenAI
import os
from typing import List, Tuple
import uuid

# Initialize models and clients
class RAGSystem:
    def __init__(self, tsv_path: str, openai_api_key: str):
        """
        Initialize the RAG system with TSV file and OpenAI API key.
        
        Args:
            tsv_path (str): Path to the TSV file
            openai_api_key (str): OpenAI API key
        """
        self.model = SentenceTransformer('nlpaueb/legal-bert-base-uncased')
        self.client = OpenAI(api_key=openai_api_key)
        self.index = None
        self.documents = []
        self.metadata = []
        self.dimension = 768  # Legal BERT embedding dimension
        self.load_and_index_documents(tsv_path)

    def load_and_index_documents(self, tsv_path: str) -> None:
        """
        Load TSV file and create FAISS index with document embeddings.
        
        Args:
            tsv_path (str): Path to the TSV file
        """
        # Load TSV
        df = pd.read_csv(tsv_path, sep="\t", compression="gzip")
        if not all(col in df.columns for col in ['name', 'type', 'content']):
            raise ValueError("TSV must contain 'name', 'type', and 'content' columns")

        # Store documents and metadata
        self.documents = df['content'].tolist()
        self.metadata = df[['name', 'type']].to_dict('records')

        # Generate embeddings
        embeddings = self.model.encode(self.documents, batch_size=32, show_progress_bar=True)

        # Initialize FAISS index
        self.index = faiss.IndexFlatL2(self.dimension)
        self.index.add(np.array(embeddings, dtype=np.float32))

    def retrieve(self, query: str, k: int = 5) -> List[Tuple[str, dict, float]]:
        """
        Retrieve top-k relevant documents for a given query.
        
        Args:
            query (str): User query
            k (int): Number of documents to retrieve
            
        Returns:
            List of (content, metadata, score) tuples
        """
        # Encode query
        query_embedding = self.model.encode([query])[0]
        
        # Search FAISS index
        distances, indices = self.index.search(np.array([query_embedding], dtype=np.float32), k)
        
        # Collect results
        results = []
        for idx, distance in zip(indices[0], distances[0]):
            if idx < len(self.documents):
                score = 1 / (1 + distance)  # Convert distance to similarity score
                results.append((self.documents[idx], self.metadata[idx], score))
        
        return results

    def generate_response(self, query: str, retrieved_docs: List[Tuple[str, dict, float]]) -> str:
        """
        Generate a response using OpenAI API with retrieved documents as context.
        
        Args:
            query (str): User query
            retrieved_docs: List of (content, metadata, score) tuples
            
        Returns:
            str: Generated response
        """
        # Prepare context from retrieved documents
        context = "\n\n".join([f"Document: {doc[0]}\nMetadata: {doc[1]}" for doc in retrieved_docs])
        
        # Construct prompt
        prompt = f"""You are a legal assistant powered by a RAG system. Use the following context to answer the query accurately and concisely. If the context doesn't provide enough information, state so and provide a general response based on your knowledge.

Context:
{context}

Query:
{query}

Answer:
"""
        
        # Call OpenAI API
        response = self.client.chat.completions.create(
            model="gpt-4.1-nano",
            messages=[
                {"role": "system", "content": "You are a helpful legal assistant."},
                {"role": "user", "content": prompt}
            ],
            max_tokens=500,
            temperature=0.7
        )
        
        return response.choices[0].message.content.strip()

    def query(self, query: str, k: int = 5) -> dict:
        """
        Process a query through the RAG pipeline.
        
        Args:
            query (str): User query
            k (int): Number of documents to retrieve
            
        Returns:
            dict: Response and retrieved documents
        """
        # Retrieve relevant documents
        retrieved_docs = self.retrieve(query, k)
        
        # Generate response
        answer = self.generate_response(query, retrieved_docs)
        
        return {
            "query": query,
            "answer": answer,
            "retrieved_documents": [
                {"content": doc[0], "metadata": doc[1], "score": doc[2]}
                for doc in retrieved_docs
            ]
        }
# Out:
# 2025-07-29 16:39:16.027783: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753807156.215768      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753807156.277257      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# !gdown 1--7L-BtJwrQB7yXcfPgV9_zQfn9nK-S5

df = pd.read_csv("bills.tsv.gz", sep="\t", compression="gzip")
df = df.rename(columns={"filename": "name"})
df["type"] = "bill"
df.to_csv('bills.tsv.gz', sep='\t', index=False, compression='gzip')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1--7L-BtJwrQB7yXcfPgV9_zQfn9nK-S5
# To: /kaggle/working/bills.tsv.gz
# 100%|██████████████████████████████████████| 6.17M/6.17M [00:00<00:00, 87.0MB/s]

# %%
from kaggle_secrets import UserSecretsClient
openai_api_key = UserSecretsClient().get_secret("openai_api_key")
tsv_path = "bills.tsv.gz"

# Initialize RAG system
rag = RAGSystem(tsv_path, openai_api_key)

# Example query
query = "What are the legal implications of a non-compete clause?"
result = rag.query(query, k=3)

# Print results
print(f"Query: {result['query']}")
print(f"Answer: {result['answer']}")
print("\nRetrieved Documents:")
for doc in result['retrieved_documents']:
    print(f"\nContent: {doc['content'][:100]}...")
    print(f"Metadata: {doc['metadata']}")
    print(f"Score: {doc['score']:.4f}")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Batches:   0%|          | 0/43 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Query: What are the legal implications of a non-compete clause?
# Answer: The provided context does not contain specific information regarding the legal implications of a non-compete clause.
#
# In general, a non-compete clause is a contractual provision that restricts an individual or entity from engaging in a business similar to that of the employer or another party for a specified period and within a certain geographic area after the termination of employment or a contractual relationship. The enforceability and legal implications of such clauses vary depending on the jurisdiction and specific circumstances, but they typically must be reasonable in scope, duration, and geographic area to be considered valid. If found overly broad or restrictive, such clauses may be deemed unenforceable by courts.
#
# For precise legal analysis or implications specific to Sri Lankan law, consulting relevant statutes or legal counsel is recommended.
#
# Retrieved Documents:
#
# Content: THE GAZETTE OF THE DEMOCRATIC SOCIALIST REPUBLIC OF SRI LANKA Part II of April 17, 2025 SUPPLEMENT (...
# Metadata: {'name': '2025-4-582-2025_E.txt', 'type': 'bill'}
# Score: 0.0325
#
# Content: PARLIAMENT OF THE DEMOCRATIC SOCIALIST REPUBLIC OF SRI LANKA COMPANIES (AMENDMENT) -------- [Bill No...
# Metadata: {'name': '2019-3-07-2019_E.txt', 'type': 'bill'}
# Score: 0.0324
#
# Content: COMPANIES (AMENDMENT) BILL to amend the Companies Act, No. 07 of 2007 -------- Presented by the Mini...
# Metadata: {'name': '2025-6-606-2025_E.txt', 'type': 'bill'}
# Score: 0.0324
